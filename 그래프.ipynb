# %%
import pandas as pd
import numpy as np

#파일 불러오기
data = pd.read_excel('./data_new.xlsx')
data
# Out:
#          name  price_rate state     date  wifi  used  capacity    type  \
# 0     아이패드에어1    0.139535     B  2021.01  wifi  7.91        64     air
# 1     아이패드에어2    0.306944     B  2021.02  wifi  6.92        64     air
# 2     아이패드프로3    0.565010     B  2020.12  wifi  2.02       256     pro
# 3       아이패드5    0.363636     C  2021.02  wifi  3.99       128  normal
# 4     아이패드에어4    0.931245     A  2020.11   lte  0.02       256     air
# ...       ...         ...   ...      ...   ...   ...       ...     ...
# 5975  아이패드프로4    0.699790     A  2020.11  wifi  0.08       256     pro
# 5976    아이패드5    0.511628     B  2020.11  wifi  3.08        32  normal
# 5977    아이패드8    0.935412     A  2021.02  wifi  0.93        32  normal
# 5978    아이패드8    0.890869     B  2021.03  wifi  0.94        32  normal
# 5979  아이패드미니2    0.230769     C  2020.12   lte  7.02        16    mini
#
#         price  price_i  generation
# 0      120000   860000           1
# 1      221000   720000           2
# ...

# %%
import math
import matplotlib.pyplot as plt
#변수와의 상관관계 바이올린 플롯으로 그리기관관계 바이올린 플롯으로 그리기
import seaborn as sns
plt.xlabel('state')
plt.ylabel('price')
sns.violinplot(x=data['state'],y=data['price'],data=data)
plt.show()

# %%
#변수와의 상관관계
plt.xlabel('price_i')
plt.ylabel('price')
plt.scatter(data[['price_i']],data[['price']],alpha=0.1,color="gray")
plt.show()

# %%
#변수와의 상관관계
plt.xlabel('used')
plt.ylabel('price')
plt.scatter(data[['used']],data[['price']],alpha=0.1,color="gray")
plt.show()

# %%
import math
import matplotlib.pyplot as plt
#변수와의 상관관계 바이올린 플롯으로 그리기관관계 바이올린 플롯으로 그리기
import seaborn as sns
plt.xlabel('type')
plt.ylabel('price')
sns.violinplot(x=data['type'],y=data['price'],data=data)
plt.show()

# %%
import math
import matplotlib.pyplot as plt
#변수와의 상관관계 바이올린 플롯으로 그리기관관계 바이올린 플롯으로 그리기
import seaborn as sns
plt.xlabel('generation')
plt.ylabel('price')
sns.violinplot(x=data['generation'],y=data['price'],data=data)
plt.show()
